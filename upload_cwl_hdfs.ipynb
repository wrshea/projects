# %%
from hdfs import InsecureClient

# %%
client = InsecureClient('http://namenode:50070', user='root')
client.delete('/Users', recursive=True)
client.list('/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f291ec05160>: Failed to establish a new connection: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/Users?user.name=root&recursive=True&op=DELETE (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec05160>: Failed to establish a new connection: [Errno 113] No route to host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-fe142a4ee247> in <module>
#       1
#       2 client = InsecureClient('http://namenode:50070', user='root')
# ----> 3 client.delete('/Users', recursive=True)
#       4 client.list('/')
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in delete(self, hdfs_path, recursive)
#     856       'Deleting %r%s.', hdfs_path, ' recursively' if recursive else ''
#     857     )
# --> 858     return self._delete(hdfs_path, recursive=recursive).json()['boolean']
#     859
#     860   def rename(self, hdfs_src_path, hdfs_dst_path):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     123           if len(client._urls) > 1:
#     124             _logger.warning('No reachable host, raising last error.')
# --> 125           raise err
#     126
#     127     api_handler.__name__ = '%s_handler' % (operation.lower(), )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     105             data=data,
#     106             params=params,
# --> 107             **self.kwargs
#     108           )
#     109         except (rq.exceptions.ReadTimeout, rq.exceptions.ConnectTimeout,
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in _request(self, method, url, **kwargs)
#     212       timeout=self._timeout,
#     213       headers={'content-type': 'application/octet-stream'}, # For HttpFS.
# --> 214       **kwargs
#     215     )
#     216
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/Users?user.name=root&recursive=True&op=DELETE (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec05160>: Failed to establish a new connection: [Errno 113] No route to host'))

# %%
client.makedirs('/Users')
client.makedirs('/Users/vagrant')
client.set_owner('/Users/vagrant', owner='vagrant', group='vagrant')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f291ec056a0>: Failed to establish a new connection: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/Users?user.name=root&op=MKDIRS (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec056a0>: Failed to establish a new connection: [Errno 113] No route to host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-74109882bc71> in <module>
# ----> 1 client.makedirs('/Users')
#       2 client.makedirs('/Users/vagrant')
#       3 client.set_owner('/Users/vagrant', owner='vagrant', group='vagrant')
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in makedirs(self, hdfs_path, permission)
#     960     """
#     961     _logger.info('Creating directories to %r.', hdfs_path)
# --> 962     self._mkdirs(hdfs_path, permission=permission)
#     963
#     964   def checksum(self, hdfs_path):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     123           if len(client._urls) > 1:
#     124             _logger.warning('No reachable host, raising last error.')
# --> 125           raise err
#     126
#     127     api_handler.__name__ = '%s_handler' % (operation.lower(), )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     105             data=data,
#     106             params=params,
# --> 107             **self.kwargs
#     108           )
#     109         except (rq.exceptions.ReadTimeout, rq.exceptions.ConnectTimeout,
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in _request(self, method, url, **kwargs)
#     212       timeout=self._timeout,
#     213       headers={'content-type': 'application/octet-stream'}, # For HttpFS.
# --> 214       **kwargs
#     215     )
#     216
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/Users?user.name=root&op=MKDIRS (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec056a0>: Failed to establish a new connection: [Errno 113] No route to host'))

# %%
client = InsecureClient('http://namenode:50070', user='vagrant')
client.list('/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f291ec14160>: Failed to establish a new connection: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/?user.name=vagrant&op=LISTSTATUS (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec14160>: Failed to establish a new connection: [Errno 113] No route to host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-35ec8796c492> in <module>
#       1 client = InsecureClient('http://namenode:50070', user='vagrant')
# ----> 2 client.list('/')
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in list(self, hdfs_path, status)
#     981     _logger.info('Listing %r.', hdfs_path)
#     982     hdfs_path = self.resolve(hdfs_path)
# --> 983     statuses = self._list_status(hdfs_path).json()['FileStatuses']['FileStatus']
#     984     if len(statuses) == 1 and (
#     985       not statuses[0]['pathSuffix'] or self.status(hdfs_path)['type'] == 'FILE'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     123           if len(client._urls) > 1:
#     124             _logger.warning('No reachable host, raising last error.')
# --> 125           raise err
#     126
#     127     api_handler.__name__ = '%s_handler' % (operation.lower(), )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     105             data=data,
#     106             params=params,
# --> 107             **self.kwargs
#     108           )
#     109         except (rq.exceptions.ReadTimeout, rq.exceptions.ConnectTimeout,
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in _request(self, method, url, **kwargs)
#     212       timeout=self._timeout,
#     213       headers={'content-type': 'application/octet-stream'}, # For HttpFS.
# --> 214       **kwargs
#     215     )
#     216
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/?user.name=vagrant&op=LISTSTATUS (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec14160>: Failed to establish a new connection: [Errno 113] No route to host'))

# %%
import os

datadir = os.path.join('/', 'home', 'vagrant','work','week7')
print(datadir)
# Out:
# /home/vagrant/work/week7

# %%
import glob

folders = glob.glob('structured*')
for folder in folders:
    jsons = glob.glob(folder + '/*.json')
    #print(jsons)
    for j in jsons:
        localreadmepath = os.path.join(datadir, j) 
        hdfspath = os.path.join('/', 'Users', 'vagrant', j)
        client.upload(hdfspath, localreadmepath)

# %%
client.list('/Users/vagrant')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/miniconda3/envs/py37/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f291ec146a0>: Failed to establish a new connection: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/Users/vagrant?user.name=vagrant&op=LISTSTATUS (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec146a0>: Failed to establish a new connection: [Errno 113] No route to host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-442e5dd59edd> in <module>
# ----> 1 client.list('/Users/vagrant')
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in list(self, hdfs_path, status)
#     981     _logger.info('Listing %r.', hdfs_path)
#     982     hdfs_path = self.resolve(hdfs_path)
# --> 983     statuses = self._list_status(hdfs_path).json()['FileStatuses']['FileStatus']
#     984     if len(statuses) == 1 and (
#     985       not statuses[0]['pathSuffix'] or self.status(hdfs_path)['type'] == 'FILE'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     123           if len(client._urls) > 1:
#     124             _logger.warning('No reachable host, raising last error.')
# --> 125           raise err
#     126
#     127     api_handler.__name__ = '%s_handler' % (operation.lower(), )
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in api_handler(client, hdfs_path, data, strict, **params)
#     105             data=data,
#     106             params=params,
# --> 107             **self.kwargs
#     108           )
#     109         except (rq.exceptions.ReadTimeout, rq.exceptions.ConnectTimeout,
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/hdfs/client.py in _request(self, method, url, **kwargs)
#     212       timeout=self._timeout,
#     213       headers={'content-type': 'application/octet-stream'}, # For HttpFS.
# --> 214       **kwargs
#     215     )
#     216
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='namenode', port=50070): Max retries exceeded with url: /webhdfs/v1/Users/vagrant?user.name=vagrant&op=LISTSTATUS (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f291ec146a0>: Failed to establish a new connection: [Errno 113] No route to host'))

# %%
# Out:
# ['README.md']
